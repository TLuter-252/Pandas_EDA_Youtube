# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
yt_df = pd.read_csv("USvideosv.csv")
yt_df.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
corr_likes = yt_df['views'].corr(yt_df['likes'])
corr_dislikes = yt_df['views'].corr(yt_df['dislikes'])
corr_table = yt_df[['views', 'likes', 'dislikes', 'comment_count']].corr()
corr_table
# Out:
#                   views     likes  dislikes  comment_count
# views          1.000000  0.849177  0.472213       0.617621
# likes          0.849177  1.000000  0.447186       0.803057
# dislikes       0.472213  0.447186  1.000000       0.700184
# comment_count  0.617621  0.803057  0.700184       1.000000

# %%
import matplotlib.pyplot as plt
import numpy as np


yt_df_top20 = yt_df.sort_values("views", ascending=False).head(20).reset_index(drop=True)


x = np.arange(len(yt_df_top20))
bar_width = 0.42

plt.figure(figsize=(12, 6))


plt.bar(
    x - bar_width / 2,
    yt_df_top20["likes"].to_numpy(),
    width=bar_width,
    color="lime",
    label="Likes",
    edgecolor="black",
    linewidth=1.2
)


plt.bar(
    x + bar_width / 2,
    -yt_df_top20["dislikes"].to_numpy(),
    width=bar_width,
    color="red",
    label="Dislikes",
    edgecolor="black",
    linewidth=1.2
)


plt.axhline(0, color="gray", linewidth=1)
plt.ylim(
    -yt_df_top20["dislikes"].max() * 1.1,
    yt_df_top20["likes"].max() * 1.1
)


views_millions = yt_df_top20["views"].to_numpy() / 1_000_000.0
plt.xticks(x, [f"{v:.1f}" for v in views_millions], rotation=45, ha="right")
plt.xlabel("Views (millions)")

plt.title("Likes and Dislikes per Top 20 Videos", fontsize=14, fontweight="bold")
plt.ylabel("Likes (Up) / Dislikes (Down)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

channel_df = (
    yt_df.groupby("channel_title")
         .agg(
             videos=("video_id", "nunique"),
             total_views=("views", "sum"),
             total_likes=("likes", "sum"),
             total_comments=("comment_count", "sum"),
         )
         .reset_index()
)


channel_df["total_views"] = channel_df["total_views"].clip(lower=1)
channel_df["total_likes"] = channel_df["total_likes"].fillna(0)
channel_df["total_comments"] = channel_df["total_comments"].fillna(0)


channel_df["like_rate"] = (channel_df["total_likes"] / channel_df["total_views"]).clip(upper=0.2)
channel_df["comment_rate"] = (channel_df["total_comments"] / channel_df["total_views"]).clip(upper=0.2)


min_videos = 3
min_total_views = 1_000_000
filtered = channel_df[(channel_df["videos"] >= min_videos) & (channel_df["total_views"] >= min_total_views)]


top20 = filtered.sort_values("like_rate", ascending=False).head(20).copy()


xmax = max(top20["like_rate"].max(), top20["comment_rate"].max())
xmax = min(0.2, round(xmax * 1.1, 3))


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 8), sharey=True)


ax1.barh(
    top20["channel_title"],
    top20["like_rate"],
    color="lime",
    edgecolor="black",
    linewidth=1.2
)
ax1.set_title("Likes per View")
ax1.set_xlabel("Ratio")
ax1.set_xlim(0, xmax)
ax1.invert_yaxis()
ax2.barh(
    top20["channel_title"],
    top20["comment_rate"],
    color="skyblue",
    edgecolor="black",
    linewidth=1.2
)
ax2.set_title("Comments per View")
ax2.set_xlabel("Ratio")
ax2.set_xlim(0, xmax)

# --- Global figure formatting ---
fig.suptitle("Top 20 Channels", fontsize=14, fontweight="bold")
plt.tight_layout()
plt.show()
