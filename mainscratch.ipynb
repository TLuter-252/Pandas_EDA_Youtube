# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
yt_df = pd.read_csv('USvideosv.csv')
#y_df = yt_df[['trending_date', 'publish_time', 'views','likes', 'dislikes', 'comment_count', 'comments_disabled', 'ratings_disabled']]
#y_df = yt_df[['trending_date', 'publish_time', 'views','likes', 'dislikes', 'comment_count']]
y_df = yt_df[['views','likes', 'dislikes', 'comment_count']]
y_df
# Out:
#           views   likes  dislikes  comment_count
# 0        748374   57527      2966          15954
# 1       2418783   97185      6146          12703
# 2       3191434  146033      5339           8181
# 3        343168   10172       666           2146
# 4       2095731  132235      1989          17518
# ...         ...     ...       ...            ...
# 40944   1685609   38160      1385           2657
# 40945   1064798   60008       382           3936
# 40946   1066451   48068      1032           3992
# 40947   5660813  192957      2846          13088
# 40948  10306119  357079    212976         144795
#
# [40949 rows x 4 columns]

# %%
# Correlation Matrix
c_matrix = y_df.corr()


# Create the heatmap
plt.figure(figsize=(8, 4))
sns.heatmap(
    c_matrix,
    annot=True,     # Display the correlation values on the heatmap
    cmap='coolwarm',# Use a diverging color palette
    vmin=0,        # Set the color scale minimum to -1
    vmax=1          # Set the color scale maximum to 1
)

plt.title('Correlation Heatmap of YouTube Video Metrics')
plt.show()
